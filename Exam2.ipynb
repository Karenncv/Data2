# %% [markdown]
# <a href="https://colab.research.google.com/github/Karenncv/Data2/blob/main/Exam2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exam two

# %%
import pandas as pd 
import numpy as np 
import plotly.express as px

# %% [markdown]
# ## 1.import the dataset

# %%
# Save the file path 
p1 = '/content/IED.xlsx'

#Read file 

d_excel = pd.read_excel(p1)

#Check 

d_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Año     28 non-null     int64
#  1   Sp      28 non-null     float64
#  2   otros   28 non-null     float64
#  3   Acsp    28 non-null     float64
#  4   Emc     28 non-null     float64
#  5   Im      28 non-null     float64
#  6   Ega     28 non-null     float64
#  7   C       28 non-null     float64
#  8   Cryh    28 non-null     float64
#  9   Tac     28 non-null     float64
#  10  Sfe     28 non-null     float64
#  11  Ssp     28 non-null     float64
#  12  Total   28 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 3.0 KB

# %% [markdown]
# ## 2.Explore

# %% [markdown]
# ### 2.1.Preview

# %%
# PREVIEW 
d_excel.shape
# Out:
# (28, 13)

# %%
d_excel.head
# Out:
# <bound method NDFrame.head of      Año           Sp         otros        Acsp          Emc           Im  \
# 0   2021   784.758955   8942.383491  246.590157   936.841693  1346.348154
# 1   2020   457.330043   7001.294941  192.761154   438.421579   893.944304
# 2   2019  2755.452676  11233.701350  364.954978  1361.537861  1499.246550
# 3   2018  2540.033488   8758.659286  204.257633  1186.916371  1309.800501
# 4   2017  3106.288809  10594.591640  213.870576  1019.004988  2368.032831
# 5   2016  2386.241172  11471.696550  291.545587  -177.014627  1843.771195
# 6   2015  2566.443454   9054.089192  193.838913   504.181422  2638.157001
# 7   2014  4731.823290  11436.878420  194.028468  2165.248927  2825.998700
# 8   2013  5111.503858  11098.915160  293.035749  3108.140644  2137.677593
# 9   2012  5450.937275   9589.041864   16.623718  2504.338288  1924.731960
# 10  2011  4667.465842   9979.582797  144.082894  2424.189723  1108.335858
# ...

# %%
d_excel.tail()
# Out:
#      Año          Sp        otros       Acsp         Emc          Im  \
# 23  1998   91.500006  2737.326256  23.625485   -6.370012  784.929604
# 24  1997  382.158977  5180.057384  11.549685  301.545050  513.622291
# 25  1996  778.298074  2333.378516  36.663081   51.179115  730.763924
# 26  1995  151.328000   817.040274  -2.033655  -64.710612  520.907416
# 27  1994  134.657093  1311.840169  21.134591   47.420703  536.297531
#
#             Ega           C        Cryh         Tac          Sfe         Ssp  \
# 23   672.296274  -51.968339  191.407042  263.303999   665.231833  194.870370
# 24  2961.572372  123.614569  116.368715   43.145246  1071.626327   37.013129
# 25   516.994558   20.194599   78.707876  125.213305   754.575923   19.086136
# 26    12.049041   43.140495    6.852152   42.278186   242.167961   16.389289
# 27     5.013310   25.386094  112.861163  248.644419   300.390145   14.692213
#
#           Total
# 23  2828.826262
# 24  5562.216362
# 25  3111.676590
# 26   968.368274
# ...

# %% [markdown]
# ### 2.2.Add more info

# %% [markdown]
# ### 2.3.Reindex

# %%
# Single index 
d_excel = d_excel.set_index('Año')
d_excel.head
# Out:
# <bound method NDFrame.head of                Sp         otros        Acsp          Emc           Im  \
# Año
# 2021   784.758955   8942.383491  246.590157   936.841693  1346.348154
# 2020   457.330043   7001.294941  192.761154   438.421579   893.944304
# 2019  2755.452676  11233.701350  364.954978  1361.537861  1499.246550
# 2018  2540.033488   8758.659286  204.257633  1186.916371  1309.800501
# 2017  3106.288809  10594.591640  213.870576  1019.004988  2368.032831
# 2016  2386.241172  11471.696550  291.545587  -177.014627  1843.771195
# 2015  2566.443454   9054.089192  193.838913   504.181422  2638.157001
# 2014  4731.823290  11436.878420  194.028468  2165.248927  2825.998700
# 2013  5111.503858  11098.915160  293.035749  3108.140644  2137.677593
# 2012  5450.937275   9589.041864   16.623718  2504.338288  1924.731960
# 2011  4667.465842   9979.582797  144.082894  2424.189723  1108.335858
# 2010  3079.774574   3350.215039   58.139719  1838.531913   209.791917
# ...

# %%
# Multiple index 
d_excel2 = df 
d_excel2 = d_excel2.set_index(['Año','Quarter'], append = True)
d_excel2.head

# %% [markdown]
# ### 2.4.Simple Graph

# %%
fig = px.line(d_excel,title = 'IED')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
